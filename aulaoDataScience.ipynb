# %% [markdown]
# <a href="https://colab.research.google.com/github/marcelopaludetto/aulao-datascience/blob/main/aulaoDataScience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Extraindo informações do Edutech

# %%
import pandas as pd

# %%
dadoSemana01 = pd.read_csv('https://raw.githubusercontent.com/marcelopaludetto/aulao-datascience/main/SEED%20-%20Semana%201.csv')
dadoSemana02 = pd.read_csv('https://raw.githubusercontent.com/marcelopaludetto/aulao-datascience/main/SEED%20-%20Semana%202.csv')
dadoSemana03 = pd.read_csv('https://raw.githubusercontent.com/marcelopaludetto/aulao-datascience/main/SEED%20-%20Semana%203.csv')
dadoSemana04 = pd.read_csv('https://raw.githubusercontent.com/marcelopaludetto/aulao-datascience/main/SEED%20-%20Semana%204.csv')
dadoSemana05 = pd.read_csv('https://raw.githubusercontent.com/marcelopaludetto/aulao-datascience/main/SEED%20-%20Semana%205.csv')
dadoSemana06 = pd.read_csv('https://raw.githubusercontent.com/marcelopaludetto/aulao-datascience/main/SEED%20-%20Semana%206.csv')
dadoSemana07 = pd.read_csv('https://raw.githubusercontent.com/marcelopaludetto/aulao-datascience/main/SEED%20-%20Semana%207.csv')
dadoSemana08 = pd.read_csv('https://raw.githubusercontent.com/marcelopaludetto/aulao-datascience/main/SEED%20-%20Semana%208.csv')
dadoSemana09 = pd.read_csv('https://raw.githubusercontent.com/marcelopaludetto/aulao-datascience/main/SEED%20-%20Semana%209.csv')
dadoSemana10 = pd.read_csv('https://raw.githubusercontent.com/marcelopaludetto/aulao-datascience/main/SEED%20-%20Semana%2010.csv')
dadoSemana11 = pd.read_csv('https://raw.githubusercontent.com/marcelopaludetto/aulao-datascience/main/SEED%20-%20Semana%2011.csv')

# %%
info = ['data', 'data de último acesso', 'id', 'cargo', 'teamId',
       'turmaTrilha', 'atividadesFeitas', 'atividadesCorretas',
       'atividadesGerais']
dadoSemana01 = dadoSemana01[info]
dadoSemana02 = dadoSemana02[info]
dadoSemana03 = dadoSemana03[info]
dadoSemana04 = dadoSemana04[info]
dadoSemana05 = dadoSemana05[info]
dadoSemana06 = dadoSemana06[info]
dadoSemana07 = dadoSemana07[info]
dadoSemana08 = dadoSemana08[info]
dadoSemana09 = dadoSemana09[info]
dadoSemana10 = dadoSemana10[info]
dadoSemana11 = dadoSemana11[info]

# %%
renomear = {'data' : 'data', 'data de último acesso' : 'data_ultimo_acesso', 'id' : 'id', 'cargo':'cargo', 'teamId':'teamId',
       'turmaTrilha':'turmaTrilha', 'atividadesFeitas':'atividadesFeitas', 'atividadesCorretas':'atividadesCorretas',
       'atividadesGerais': 'atividadesGerais'}

# %%
dadoSemana01 = dadoSemana01.rename(columns = renomear)
dadoSemana02 = dadoSemana02.rename(columns = renomear)
dadoSemana03 = dadoSemana03.rename(columns = renomear)
dadoSemana04 = dadoSemana04.rename(columns = renomear)
dadoSemana05 = dadoSemana05.rename(columns = renomear)
dadoSemana06 = dadoSemana06.rename(columns = renomear)
dadoSemana07 = dadoSemana07.rename(columns = renomear)
dadoSemana08 = dadoSemana08.rename(columns = renomear)
dadoSemana09 = dadoSemana09.rename(columns = renomear)
dadoSemana10 = dadoSemana10.rename(columns = renomear)
dadoSemana11 = dadoSemana11.rename(columns = renomear)

# %%
print('Na 1 semana, o número de estudantes matriculados no Edutech é de {}'.format(dadoSemana01.data.count()))
print('Na 2 semana, o número de estudantes matriculados no Edutech é de {}'.format(dadoSemana02.data.count()))
print('Na 3 semana, o número de estudantes matriculados no Edutech é de {}'.format(dadoSemana03.data.count()))
print('Na 4 semana, o número de estudantes matriculados no Edutech é de {}'.format(dadoSemana04.data.count()))
print('Na 5 semana, o número de estudantes matriculados no Edutech é de {}'.format(dadoSemana05.data.count()))
print('Na 6 semana, o número de estudantes matriculados no Edutech é de {}'.format(dadoSemana06.data.count()))
print('Na 7 semana, o número de estudantes matriculados no Edutech é de {}'.format(dadoSemana07.data.count()))
print('Na 8 semana, o número de estudantes matriculados no Edutech é de {}'.format(dadoSemana08.data.count()))
print('Na 9 semana, o número de estudantes matriculados no Edutech é de {}'.format(dadoSemana09.data.count()))
print('Na 10 semana, o número de estudantes matriculados no Edutech é de {}'.format(dadoSemana10.data.count()))
print('Na 11 semana, o número de estudantes matriculados no Edutech é de {}'.format(dadoSemana11.data.count()))
# Out:
# Na 1 semana, o número de estudantes matriculados no Edutech é de 67487
# Na 2 semana, o número de estudantes matriculados no Edutech é de 67487
# Na 3 semana, o número de estudantes matriculados no Edutech é de 67487
# Na 4 semana, o número de estudantes matriculados no Edutech é de 67487
# Na 5 semana, o número de estudantes matriculados no Edutech é de 67488
# Na 6 semana, o número de estudantes matriculados no Edutech é de 67745
# Na 7 semana, o número de estudantes matriculados no Edutech é de 70776
# Na 8 semana, o número de estudantes matriculados no Edutech é de 70842
# Na 9 semana, o número de estudantes matriculados no Edutech é de 47923
# Na 10 semana, o número de estudantes matriculados no Edutech é de 48010
# Na 11 semana, o número de estudantes matriculados no Edutech é de 48008

# %%
print('Na semana 7 foram incluidos {} estudantes no programa Edutech'.format(dadoSemana07.data.count() - dadoSemana06.data.count()))
# Out:
# Na semana 7 foram incluidos 3031 estudantes no programa Edutech

# %%
print('Na 9 semana, foram excluídos {} estudantes do programa Edutech'.format(dadoSemana08.data.count() - dadoSemana09.data.count()))
# Out:
# Na 9 semana, foram excluídos 22919 estudantes do programa Edutech

# %% [markdown]
# ## Coletando o número de alunos ativos

# %%
dadoSemana01['atividadesGerais'].notnull()
dadoSemana02['atividadesGerais'].notnull()
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 67482    False
# 67483    False
# 67484    False
# 67485    False
# 67486    False
# Name: atividadesGerais, Length: 67487, dtype: bool

# %%
dadosAtivos01 = dadoSemana01[dadoSemana01['atividadesGerais'].notnull()]
dadosAtivos02 = dadoSemana02[dadoSemana02['atividadesGerais'].notnull()]
dadosAtivos03 = dadoSemana03[dadoSemana03['atividadesGerais'].notnull()]
dadosAtivos04 = dadoSemana04[dadoSemana04['atividadesGerais'].notnull()]
dadosAtivos05 = dadoSemana05[dadoSemana05['atividadesGerais'].notnull()]
dadosAtivos06 = dadoSemana06[dadoSemana06['atividadesGerais'].notnull()]
dadosAtivos07 = dadoSemana07[dadoSemana07['atividadesGerais'].notnull()]
dadosAtivos08 = dadoSemana08[dadoSemana08['atividadesGerais'].notnull()]
dadosAtivos09 = dadoSemana09[dadoSemana09['atividadesGerais'].notnull()]
dadosAtivos10 = dadoSemana10[dadoSemana10['atividadesGerais'].notnull()]
dadosAtivos11 = dadoSemana11[dadoSemana11['atividadesGerais'].notnull()]

# %%
print('Na 1 semana, o número de estudantes ativos no Edutech é de {}'.format(dadosAtivos01.data.count()))
print('Na 2 semana, o número de estudantes ativos no Edutech é de {}'.format(dadosAtivos02.data.count()))
print('Na 3 semana, o número de estudantes ativos no Edutech é de {}'.format(dadosAtivos03.data.count()))
print('Na 4 semana, o número de estudantes ativos no Edutech é de {}'.format(dadosAtivos04.data.count()))
print('Na 5 semana, o número de estudantes ativos no Edutech é de {}'.format(dadosAtivos05.data.count()))
print('Na 6 semana, o número de estudantes ativos no Edutech é de {}'.format(dadosAtivos06.data.count()))
print('Na 7 semana, o número de estudantes ativos no Edutech é de {}'.format(dadosAtivos07.data.count()))
print('Na 8 semana, o número de estudantes ativos no Edutech é de {}'.format(dadosAtivos08.data.count()))
print('Na 9 semana, o número de estudantes ativos no Edutech é de {}'.format(dadosAtivos09.data.count()))
print('Na 10 semana, o número de estudantes ativos no Edutech é de {}'.format(dadosAtivos10.data.count()))
print('Na 11 semana, o número de estudantes ativos no Edutech é de {}'.format(dadosAtivos11.data.count()))
# Out:
# Na 1 semana, o número de estudantes ativos no Edutech é de 6358
# Na 2 semana, o número de estudantes ativos no Edutech é de 6619
# Na 3 semana, o número de estudantes ativos no Edutech é de 6664
# Na 4 semana, o número de estudantes ativos no Edutech é de 6696
# Na 5 semana, o número de estudantes ativos no Edutech é de 6485
# Na 6 semana, o número de estudantes ativos no Edutech é de 6879
# Na 7 semana, o número de estudantes ativos no Edutech é de 5592
# Na 8 semana, o número de estudantes ativos no Edutech é de 6439
# Na 9 semana, o número de estudantes ativos no Edutech é de 6538
# Na 10 semana, o número de estudantes ativos no Edutech é de 6352
# Na 11 semana, o número de estudantes ativos no Edutech é de 5395

# %%
percentual01 = dadoSemana01.atividadesGerais.count()/dadoSemana01.data.count() * 100
percentual02 = dadoSemana02.atividadesGerais.count()/dadoSemana02.data.count() * 100
percentual03 = dadoSemana03.atividadesGerais.count()/dadoSemana03.data.count() * 100
percentual04 = dadoSemana04.atividadesGerais.count()/dadoSemana04.data.count() * 100
percentual05 = dadoSemana05.atividadesGerais.count()/dadoSemana05.data.count() * 100
percentual06 = dadoSemana06.atividadesGerais.count()/dadoSemana06.data.count() * 100
percentual07 = dadoSemana07.atividadesGerais.count()/dadoSemana07.data.count() * 100
percentual08 = dadoSemana08.atividadesGerais.count()/dadoSemana08.data.count() * 100
percentual09 = dadoSemana09.atividadesGerais.count()/dadoSemana09.data.count() * 100
percentual10 = dadoSemana10.atividadesGerais.count()/dadoSemana10.data.count() * 100
percentual11 = dadoSemana11.atividadesGerais.count()/dadoSemana11.data.count() * 100


print('Na semana 01 tivemos a porcentagem de alunos ativos no Edutech é de {} %'.format(percentual01.round(2)))
print('Na semana 02 tivemos a porcentagem de alunos ativos no Edutech é de {} %'.format(percentual02.round(2)))
print('Na semana 03 tivemos a porcentagem de alunos ativos no Edutech é de {} %'.format(percentual03.round(2)))
print('Na semana 04 tivemos a porcentagem de alunos ativos no Edutech é de {} %'.format(percentual04.round(2)))
print('Na semana 05 tivemos a porcentagem de alunos ativos no Edutech é de {} %'.format(percentual05.round(2)))
print('Na semana 06 tivemos a porcentagem de alunos ativos no Edutech é de {} %'.format(percentual06.round(2)))
print('Na semana 07 tivemos a porcentagem de alunos ativos no Edutech é de {} %'.format(percentual07.round(2)))
print('Na semana 08 tivemos a porcentagem de alunos ativos no Edutech é de {} %'.format(percentual08.round(2)))
print('Na semana 09 tivemos a porcentagem de alunos ativos no Edutech é de {} %'.format(percentual09.round(2)))
print('Na semana 10 tivemos a porcentagem de alunos ativos no Edutech é de {} %'.format(percentual10.round(2)))
print('Na semana 11 tivemos a porcentagem de alunos ativos no Edutech é de {} %'.format(percentual11.round(2)))
# Out:
# Na semana 01 tivemos a porcentagem de alunos ativos no Edutech é de 9.42 %
# Na semana 02 tivemos a porcentagem de alunos ativos no Edutech é de 9.81 %
# Na semana 03 tivemos a porcentagem de alunos ativos no Edutech é de 9.87 %
# Na semana 04 tivemos a porcentagem de alunos ativos no Edutech é de 9.92 %
# Na semana 05 tivemos a porcentagem de alunos ativos no Edutech é de 9.61 %
# Na semana 06 tivemos a porcentagem de alunos ativos no Edutech é de 10.15 %
# Na semana 07 tivemos a porcentagem de alunos ativos no Edutech é de 7.9 %
# Na semana 08 tivemos a porcentagem de alunos ativos no Edutech é de 9.09 %
# Na semana 09 tivemos a porcentagem de alunos ativos no Edutech é de 13.64 %
# Na semana 10 tivemos a porcentagem de alunos ativos no Edutech é de 13.23 %
# Na semana 11 tivemos a porcentagem de alunos ativos no Edutech é de 11.24 %

# %% [markdown]
# # Gráficos

# %%
import seaborn as sns

# %%
plt = sns.scatterplot(x='data_ultimo_acesso',y='atividadesFeitas', data=dados01)
plt.figure.set_size_inches(24,6)

# %%
dadosAtivos01 = dados01.query("atividadesGerais > 0")
dadosAtivos02 = dados02.query("atividadesGerais > 0")

# %%
plt = sns.scatterplot(x='data_ultimo_acesso',y='atividadesFeitas', data=dadosAtivos01)
plt.figure.set_size_inches(24,6)

# %%
plt = sns.scatterplot(x='data_ultimo_acesso',y='atividadesFeitas', data=dadosAtivos02)
plt.figure.set_size_inches(24,6)

# %%
plt = sns.boxplot(x='data_ultimo_acesso',y='atividadesFeitas', data=dadosAtivos01)
plt.figure.set_size_inches(24,6)

# %%
plt = sns.boxplot(x='data_ultimo_acesso',y='atividadesFeitas', data=dadosAtivos02)
plt.figure.set_size_inches(24,6)

# %%
dadosAtivos01 = dadosAtivos01.sort_values(by = ['data_ultimo_acesso'])

# %%
dadosAtivos02 = dadosAtivos02.sort_values(by = ['data_ultimo_acesso'])

# %%
plt = sns.relplot(x='data_ultimo_acesso',y='atividadesFeitas', data=dadosAtivos01)
plt.figure.set_size_inches(24,6)

# %%
plt = sns.relplot(x='data_ultimo_acesso',y='atividadesFeitas', data=dadosAtivos02)
plt.figure.set_size_inches(24,6)

# %%
selecao = dadosAtivos02['data_ultimo_acesso'] == '2021-05-04'
dia04maioSemana2 = dadosAtivos02[selecao]
dia04maioSemana2
# Out:
#              data data_ultimo_acesso  ...  atividadesCorretas atividadesGerais
# 20649  2021-04-26         2021-05-04  ...                   0              6.0
# 19745  2021-04-26         2021-05-04  ...                   0              3.0
# 64978  2021-04-26         2021-05-04  ...                   0              3.0
# 9451   2021-04-26         2021-05-04  ...                   0              2.0
# 19963  2021-04-26         2021-05-04  ...                   0              1.0
# ...           ...                ...  ...                 ...              ...
# 28533  2021-04-26         2021-05-04  ...                   0              1.0
# 31514  2021-04-26         2021-05-04  ...                   0              3.0
# 31506  2021-04-26         2021-05-04  ...                   0             19.0
# 2621   2021-04-26         2021-05-04  ...                   2             10.0
# 3207   2021-04-26         2021-05-04  ...                   1              7.0
#
# [782 rows x 9 columns]

# %%
selecao = dadosAtivos01['data_ultimo_acesso'] == '2021-05-04'
dia04maioSemana1 = dadosAtivos01[selecao]
dia04maioSemana1
# Out:
#              data data_ultimo_acesso  ...  atividadesCorretas atividadesGerais
# 42501  2021-04-19         2021-05-04  ...                   0              3.0
# 1977   2021-04-19         2021-05-04  ...                   4             13.0
# 215    2021-04-19         2021-05-04  ...                  22             66.0
# 57463  2021-04-19         2021-05-04  ...                   0              4.0
# 962    2021-04-19         2021-05-04  ...                   9             25.0
# ...           ...                ...  ...                 ...              ...
# 1122   2021-04-19         2021-05-04  ...                   9             16.0
# 9504   2021-04-19         2021-05-04  ...                   0              5.0
# 38567  2021-04-19         2021-05-04  ...                   0             21.0
# 63743  2021-04-19         2021-05-04  ...                   0              2.0
# 38261  2021-04-19         2021-05-04  ...                   0             10.0
#
# [679 rows x 9 columns]

# %%
dia04maioSemana1['id'] == '584339'
# Out:
# 42501    False
# 1977     False
# 215      False
# 57463    False
# 962      False
#          ...
# 1122     False
# 9504     False
# 38567    False
# 63743    False
# 38261    False
# Name: id, Length: 679, dtype: bool

# %% [markdown]
# # Análise de Frequências
